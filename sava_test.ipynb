# %%
# !pip install seaborn
# Out:
# ...
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/59.7 kB ? eta -:--:--
#      -------------------------------- ----- 51.2/59.7 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 59.7/59.7 kB 532.3 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      --------- ------------------------------ 41.0/165.9 kB ? eta -:--:--
#      -------------------------------------  163.8/165.9 kB 2.0 MB/s eta 0:00:01
#      -------------------------------------- 165.9/165.9 kB 1.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    --------------- ------------------------ 112.6/294.9 kB ? eta -:--:--
#    -------------------------------------- - 286.7/294.9 kB 3.5 MB/s eta 0:00:01
# ...

# %%
import json
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import json file
with open("raw_data.json",'r') as file:
    data = json.load(file)

# %%
# convert to df
df = pd.DataFrame(data)
# analysis/cleaning
df.head()
df.describe()
# Out:
#         current_nA       time_s  substrate_reference_mM
# count  8985.000000  8985.000000             8985.000000
# mean      4.933163  4492.000000               10.221629
# std       3.993396  2593.890418                9.645247
# min       0.065761     0.000000                0.000000
# 25%       1.108540  2246.000000                1.052550
# 50%       3.879890  4492.000000                8.926550
# 75%       8.069797  6738.000000               17.828050
# max      39.747744  8984.000000               29.345600

# %%
# convert time to int
df['time_s'].astype(int)
# Out:
#       current_nA  time_s  substrate_reference_mM
# 0      39.747744       0                  0.0000
# 1      26.407684       1                  0.0000
# 2      21.992312       2                  0.0000
# 3      19.455822       3                  0.0000
# 4      17.868166       4                  0.0000
# ...          ...     ...                     ...
# 8980   13.471583    8980                 29.3456
# 8981   13.480977    8981                 29.3456
# 8982   13.480977    8982                 29.3456
# 8983   13.490371    8983                 29.3456
# 8984   13.513857    8984                 29.3456
#
# [8985 rows x 3 columns]

# %%
# visualise
# Plot the data
plt.plot(df['time_s'], df['current_nA'], label="Current (nA)")
plt.plot(df['time_s'], df['substrate_reference_mM'], label="substrate_reference_mM")
ax2 = ax1.twinx()  
plt.xlabel('Time (s)')
plt.ylabel('Values')
plt.show()

# %%
#define colors to use
col1 = 'steelblue'
col2 = 'red'
# define subplots
fig, ax = plt.subplots()
# current line
ax.plot(df.time_s,df.current_nA, color= col1)

# x axis label
ax.set_xlabel('Time (s)')
# y-axis label
ax.set_ylabel('Current', color = col1)
#define second y-axis that shares x-axis with current plot
ax2 = ax.twinx()
# add second glucose line
ax2.plot(df.time_s,df.substrate_reference_mM, color= col2)
# y-axis label
ax2.set_ylabel('Guclose', color = col2)
# Out:
# Text(0, 0.5, 'Guclose')

# %%
# covariance and correlation
# covariance = how two variables change together, same or opposite direction 
# direction and strength of this
# 1 means positive, as one increases, so does the other
# -1 as one increases, other decreases
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 2
#       1 # analyse data
# ----> 2 print(data.head())
#       3 # time_s = time of measurement
#       4 # current_nA: electrical current
#       5 # substance_reference_mM glucose concerntration
#
# AttributeError: 'dict' object has no attribute 'head'

# %%
## correlation current_nA vs substrate_reference_mM
correlation = df['current_nA'].corr(df['substrate_reference_mM'])
print(f'coorelation is {correlation}')
# Out:
# coorelation is 0.9603775627865698

# %%
df['substrate_reference_mM']

# %%
#for i in data["time_s"]:
 #   print(i)

df = pd.DataFrame(data)
# Plot the data
plt.plot(df['time_s'], df['current_nA'], label="Current (nA)")
plt.plot(df['time_s'], df['substrate_reference_mM'], label="substrate_reference_mM")
plt.show()

# %%
print(df.head())
# Out:
#    current_nA  time_s  substrate_reference_mM
# 0   39.747744       0                     0.0
# 1   26.407684       1                     0.0
# 2   21.992312       2                     0.0
# 3   19.455822       3                     0.0
# 4   17.868166       4                     0.0
